# %% [markdown]
# # APRIORI ALGORITHM
# -----

# %%
import numpy as np 
import pandas as pd

# %%
data_ = pd.read_csv("sepet.csv")

# %%
data_
# Out:
#               shrimp            almonds      avocado    vegetables mix  \
# 0            burgers          meatballs         eggs               NaN
# 1            chutney                NaN          NaN               NaN
# 2             turkey            avocado          NaN               NaN
# 3      mineral water               milk   energy bar  whole wheat rice
# 4     low fat yogurt                NaN          NaN               NaN
# ...              ...                ...          ...               ...
# 7495          butter         light mayo  fresh bread               NaN
# 7496         burgers  frozen vegetables         eggs      french fries
# 7497         chicken                NaN          NaN               NaN
# 7498        escalope          green tea          NaN               NaN
# 7499            eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#      green grapes whole weat flour yams cottage cheese energy drink  \
# ...

# %%
result = []

# %%
for i in range(7500):

    result.append([str(data_.values[i, j]) for j in range(1, 16)])

# %%
from apyori import apriori

# %%
apriori = apriori(result, min_support = 0.01, min_confidence = 0.2, min_lift = 3, min_length = 2)

# %%
for y in apriori:

    print(list(y))
# Out:
# [frozenset({'ground beef', 'frozen vegetables'}), 0.010266666666666667, [OrderedStatistic(items_base=frozenset({'frozen vegetables'}), items_add=frozenset({'ground beef'}), confidence=0.22514619883040934, lift=3.253557786566609)]]
# [frozenset({'spaghetti', 'ground beef'}), 0.029066666666666668, [OrderedStatistic(items_base=frozenset({'ground beef'}), items_add=frozenset({'spaghetti'}), confidence=0.4200385356454721, lift=3.3091271190557148), OrderedStatistic(items_base=frozenset({'spaghetti'}), items_add=frozenset({'ground beef'}), confidence=0.22899159663865545, lift=3.3091271190557148)]]
# [frozenset({'milk', 'soup'}), 0.012933333333333333, [OrderedStatistic(items_base=frozenset({'soup'}), items_add=frozenset({'milk'}), confidence=0.3222591362126246, lift=3.055554388868122)]]
# ...
